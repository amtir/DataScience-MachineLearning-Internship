# %% [markdown]
# <h2>Demo 1 - Visualize Data using Scatter Plot </h2>
#
# In this demo, you will be shown how scatterplot reveals correlation between two vairables.

# %%
#Step1: Import the required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

# %%
#Step2: Load the built-in dataset
tips = sns.load_dataset("tips")
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
#Step3: Fetch the preview of dataset
tips.head(10)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 5       25.29  4.71    Male     No  Sun  Dinner     4
# 6        8.77  2.00    Male     No  Sun  Dinner     2
# 7       26.88  3.12    Male     No  Sun  Dinner     4
# 8       15.04  1.96    Male     No  Sun  Dinner     2
# 9       14.78  3.23    Male     No  Sun  Dinner     2

# %%
#Step4: Obtain generic mathematical details
tips.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
#Step5: Visualize basic scatter plot
sns.lmplot(x="total_bill", y="tip", data=tips)

# %% [markdown]
# - The linear line across the plot shows the <i>trend of the tip</i> given by the customers as per the total bill.
#
# - The data points farther away from the line (top-right) are the <b>outliers</b> or exceptions in the dataset.
#
# - The <b>convergent point</b> is the <i>statistical mean</i> or the generalized prediction of the tip value on a daily basis.
#
# For <b>sns.lmplot()</b>, there are three mandatory parameters as illustrated above. There is also an optional <b>hue</b> parameter that takes in categorical columns and helps group the data plot as per hue parameter values.

# %%
#Step6: Visualize basic scatter plot with hue parameter
sns.lmplot(x="total_bill", y="tip", hue="sex", data=tips)

# %% [markdown]
# From the above plot, we can concur that while females are mostly sticking to the convergent point and tip the usual amount, quite a few males tip (exceptionally) more or less. So, hue helped us visualize this difference in separate color plotting.

# %%
#Step7: Visualize basic scatter plot with marker parameter
sns.lmplot(x="total_bill", y="tip", hue="sex", data=tips, markers=["o","x"])

# %%
#Step8: Visualization on separate facets
sns.lmplot(x="total_bill", y="tip", col="sex", data=tips)

# %%
sns.lmplot(x="total_bill", y="tip", row="smoker", col="sex", data=tips)

# %% [markdown]
# This way, you can drill deeper into you data, where tip is still given against total bill but is now also segmented into whether a smoker or not along with dependency on gender.
