# %%
import pandas as pd
dataset = pd.read_csv("player.csv")
print(dataset)
# Out:
#    rank             name  matches  innings  runs  highest  100s  50s
# 0     1          V Kohli      207      199  6283      113     5   42
# 1     2         S Dhawan      194      191  5784      106     2   44
# 2     3     Rohit Sharma      213      208  5611      109     1   40
# 3     4     Suresh Raina      205      200  5528      100     1   39
# 4     5     David Warner      150      150  5449      126     4   50
# 5     6  A B de Villiers      184      170  5162      133     3   40
# 6     7      Chris Gayle      142      141  4965      175     6   31
# 7     8        M S Dhoni      220      193  4746       84     0   23
# 8     9    Robin Uthappa      193      186  4722       87     0   25
# 9    10    Gutam Gambhir      154      152  4217       93     0   36

# %%
#first 5 rows of dataset
dataset.head() #by default it will give you first 5
# Out:
#    rank          name  matches  innings  runs  highest  100s  50s
# 0     1       V Kohli      207      199  6283      113     5   42
# 1     2      S Dhawan      194      191  5784      106     2   44
# 2     3  Rohit Sharma      213      208  5611      109     1   40
# 3     4  Suresh Raina      205      200  5528      100     1   39
# 4     5  David Warner      150      150  5449      126     4   50

# %%
#last 5 rows
dataset.tail(6)
# Out:
#    rank             name  matches  innings  runs  highest  100s  50s
# 4     5     David Warner      150      150  5449      126     4   50
# 5     6  A B de Villiers      184      170  5162      133     3   40
# 6     7      Chris Gayle      142      141  4965      175     6   31
# 7     8        M S Dhoni      220      193  4746       84     0   23
# 8     9    Robin Uthappa      193      186  4722       87     0   25
# 9    10    Gutam Gambhir      154      152  4217       93     0   36

# %%
#fetch first 5 names names of name column

dataset.name.head(6)
# Out:
# 0            V Kohli
# 1           S Dhawan
# 2       Rohit Sharma
# 3       Suresh Raina
# 4       David Warner
# 5    A B de Villiers
# Name: name, dtype: object

# %%
dataset.name.tail(6)
# Out:
# 4       David Warner
# 5    A B de Villiers
# 6        Chris Gayle
# 7          M S Dhoni
# 8      Robin Uthappa
# 9      Gutam Gambhir
# Name: name, dtype: object

# %%
dataset['matches'].sum()
# Out:
# 1862

# %%
dataset.matches.sum()
# Out:
# 1862

# %%
#on multiple columns

dataset[['runs','highest']].min()
# Out:
# runs       4217
# highest      84
# dtype: int64

# %%
#fetch row
dataset.iloc[6]
# Out:
# rank                 7
# name       Chris Gayle
# matches            142
# innings            141
# runs              4965
# highest            175
# 100s                 6
# 50s                 31
# Name: 6, dtype: object

# %%
dataset.loc[1:3]   #label-based indexing
# Out:
#    rank          name  matches  innings  runs  highest  100s  50s
# 1     2      S Dhawan      194      191  5784      106     2   44
# 2     3  Rohit Sharma      213      208  5611      109     1   40
# 3     4  Suresh Raina      205      200  5528      100     1   39

# %%
dataset.iloc[1:3]  #integer based indexing
# Out:
#    rank          name  matches  innings  runs  highest  100s  50s
# 1     2      S Dhawan      194      191  5784      106     2   44
# 2     3  Rohit Sharma      213      208  5611      109     1   40

# %%
data = {'name':['Charlie','Anu','Sujatha','Caty'],'age':[23,22,24,23]}
df = pd.DataFrame(data)
print(df)
# Out:
#       name  age
# 0  Charlie   23
# 1      Anu   22
# 2  Sujatha   24
# 3     Caty   23

# %%
ritesh = df[df.name.str.startswith('C')]
print(ritesh)
# Out:
#       name  age
# 0  Charlie   23
# 3     Caty   23

# %%
#summary of dataset

dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   rank     10 non-null     int64
#  1   name     10 non-null     object
#  2   matches  10 non-null     int64
#  3   innings  10 non-null     int64
#  4   runs     10 non-null     int64
#  5   highest  10 non-null     int64
#  6   100s     10 non-null     int64
#  7   50s      10 non-null     int64
# dtypes: int64(7), object(1)
# memory usage: 772.0+ bytes

# %%
#statastical info about dataset

dataset.describe()
# Out:
#            rank     matches     innings         runs     highest      100s  \
# count  10.00000   10.000000   10.000000    10.000000   10.000000  10.00000
# mean    5.50000  186.200000  179.000000  5246.700000  112.600000   2.20000
# std     3.02765   28.007142   23.958297   604.446496   27.002881   2.20101
# min     1.00000  142.000000  141.000000  4217.000000   84.000000   0.00000
# 25%     3.25000  161.500000  156.500000  4800.750000   94.750000   0.25000
# 50%     5.50000  193.500000  188.500000  5305.500000  107.500000   1.50000
# 75%     7.75000  206.500000  197.500000  5590.250000  122.750000   3.75000
# max    10.00000  220.000000  208.000000  6283.000000  175.000000   6.00000
#
#              50s
# count  10.000000
# mean   37.000000
# std     8.445906
# min    23.000000
# 25%    32.250000
# 50%    39.500000
# 75%    41.500000
# max    50.000000

# %%
dataset['matches'].describe()
# Out:
# count     10.000000
# mean     186.200000
# std       28.007142
# min      142.000000
# 25%      161.500000
# 50%      193.500000
# 75%      206.500000
# max      220.000000
# Name: matches, dtype: float64

# %%
dataset.innings.describe()
# Out:
# count     10.000000
# mean     179.000000
# std       23.958297
# min      141.000000
# 25%      156.500000
# 50%      188.500000
# 75%      197.500000
# max      208.000000
# Name: innings, dtype: float64

# %%
dataset[['innings','matches']].describe()
# Out:
#           innings     matches
# count   10.000000   10.000000
# mean   179.000000  186.200000
# std     23.958297   28.007142
# min    141.000000  142.000000
# 25%    156.500000  161.500000
# 50%    188.500000  193.500000
# 75%    197.500000  206.500000
# max    208.000000  220.000000

# %%
#create a column in dataset
dataset['Total'] = dataset['innings']+dataset['matches']
print(dataset)
# Out:
#    rank             name  matches  innings  runs  highest  100s  50s  Total
# 0     1          V Kohli      207      199  6283      113     5   42    406
# 1     2         S Dhawan      194      191  5784      106     2   44    385
# 2     3     Rohit Sharma      213      208  5611      109     1   40    421
# 3     4     Suresh Raina      205      200  5528      100     1   39    405
# 4     5     David Warner      150      150  5449      126     4   50    300
# 5     6  A B de Villiers      184      170  5162      133     3   40    354
# 6     7      Chris Gayle      142      141  4965      175     6   31    283
# 7     8        M S Dhoni      220      193  4746       84     0   23    413
# 8     9    Robin Uthappa      193      186  4722       87     0   25    379
# 9    10    Gutam Gambhir      154      152  4217       93     0   36    306

# %%
#remove the total column

dataset.drop('Total',axis=1)
# Out:
#    rank             name  matches  innings  runs  highest  100s  50s
# 0     1          V Kohli      207      199  6283      113     5   42
# 1     2         S Dhawan      194      191  5784      106     2   44
# 2     3     Rohit Sharma      213      208  5611      109     1   40
# 3     4     Suresh Raina      205      200  5528      100     1   39
# 4     5     David Warner      150      150  5449      126     4   50
# 5     6  A B de Villiers      184      170  5162      133     3   40
# 6     7      Chris Gayle      142      141  4965      175     6   31
# 7     8        M S Dhoni      220      193  4746       84     0   23
# 8     9    Robin Uthappa      193      186  4722       87     0   25
# 9    10    Gutam Gambhir      154      152  4217       93     0   36

# %%
#for dropping rows

dataset.drop(6,axis=0)
# Out:
#    rank             name  matches  innings  runs  highest  100s  50s  Total
# 0     1          V Kohli      207      199  6283      113     5   42    406
# 1     2         S Dhawan      194      191  5784      106     2   44    385
# 2     3     Rohit Sharma      213      208  5611      109     1   40    421
# 3     4     Suresh Raina      205      200  5528      100     1   39    405
# 4     5     David Warner      150      150  5449      126     4   50    300
# 5     6  A B de Villiers      184      170  5162      133     3   40    354
# 7     8        M S Dhoni      220      193  4746       84     0   23    413
# 8     9    Robin Uthappa      193      186  4722       87     0   25    379
# 9    10    Gutam Gambhir      154      152  4217       93     0   36    306

# %%
dataset.drop([1,3,5], axis=0)
# Out:
#    rank           name  matches  innings  runs  highest  100s  50s  Total
# 0     1        V Kohli      207      199  6283      113     5   42    406
# 2     3   Rohit Sharma      213      208  5611      109     1   40    421
# 4     5   David Warner      150      150  5449      126     4   50    300
# 6     7    Chris Gayle      142      141  4965      175     6   31    283
# 7     8      M S Dhoni      220      193  4746       84     0   23    413
# 8     9  Robin Uthappa      193      186  4722       87     0   25    379
# 9    10  Gutam Gambhir      154      152  4217       93     0   36    306

# %%
dataset.drop(dataset.loc[0:2].index)
# Out:
#    rank             name  matches  innings  runs  highest  100s  50s  Total
# 3     4     Suresh Raina      205      200  5528      100     1   39    405
# 4     5     David Warner      150      150  5449      126     4   50    300
# 5     6  A B de Villiers      184      170  5162      133     3   40    354
# 6     7      Chris Gayle      142      141  4965      175     6   31    283
# 7     8        M S Dhoni      220      193  4746       84     0   23    413
# 8     9    Robin Uthappa      193      186  4722       87     0   25    379
# 9    10    Gutam Gambhir      154      152  4217       93     0   36    306

# %%
dataset.drop(dataset.index[0:2],axis=0)
# Out:
#    rank             name  matches  innings  runs  highest  100s  50s  Total
# 2     3     Rohit Sharma      213      208  5611      109     1   40    421
# 3     4     Suresh Raina      205      200  5528      100     1   39    405
# 4     5     David Warner      150      150  5449      126     4   50    300
# 5     6  A B de Villiers      184      170  5162      133     3   40    354
# 6     7      Chris Gayle      142      141  4965      175     6   31    283
# 7     8        M S Dhoni      220      193  4746       84     0   23    413
# 8     9    Robin Uthappa      193      186  4722       87     0   25    379
# 9    10    Gutam Gambhir      154      152  4217       93     0   36    306

# %%
print(dataset)
# Out:
#    rank             name  matches  innings  runs  highest  100s  50s  Total
# 0     1          V Kohli      207      199  6283      113     5   42    406
# 1     2         S Dhawan      194      191  5784      106     2   44    385
# 2     3     Rohit Sharma      213      208  5611      109     1   40    421
# 3     4     Suresh Raina      205      200  5528      100     1   39    405
# 4     5     David Warner      150      150  5449      126     4   50    300
# 5     6  A B de Villiers      184      170  5162      133     3   40    354
# 6     7      Chris Gayle      142      141  4965      175     6   31    283
# 7     8        M S Dhoni      220      193  4746       84     0   23    413
# 8     9    Robin Uthappa      193      186  4722       87     0   25    379
# 9    10    Gutam Gambhir      154      152  4217       93     0   36    306

# %%
#set_value   instead use .at[]

dataset.at[7,'name'] = 'thala'
print(dataset)
# Out:
#    rank             name  matches  innings  runs  highest  100s  50s  Total
# 0     1          V Kohli      207      199  6283      113     5   42    406
# 1     2         S Dhawan      194      191  5784      106     2   44    385
# 2     3     Rohit Sharma      213      208  5611      109     1   40    421
# 3     4     Suresh Raina      205      200  5528      100     1   39    405
# 4     5     David Warner      150      150  5449      126     4   50    300
# 5     6  A B de Villiers      184      170  5162      133     3   40    354
# 6     7      Chris Gayle      142      141  4965      175     6   31    283
# 7     8            thala      220      193  4746       84     0   23    413
# 8     9    Robin Uthappa      193      186  4722       87     0   25    379
# 9    10    Gutam Gambhir      154      152  4217       93     0   36    306

# %%
#update values in a dataset

data = {'runs':['56','89','76'],'100s':['5','8','4']}
a = pd.DataFrame(data)
dataset.update(a)
print(dataset)
# Out:
#    rank             name  matches  innings  runs  highest 100s  50s  Total
# 0     1          V Kohli      207      199    56      113    5   42    406
# 1     2         S Dhawan      194      191    89      106    8   44    385
# 2     3     Rohit Sharma      213      208    76      109    4   40    421
# 3     4     Suresh Raina      205      200  5528      100    1   39    405
# 4     5     David Warner      150      150  5449      126    4   50    300
# 5     6  A B de Villiers      184      170  5162      133    3   40    354
# 6     7      Chris Gayle      142      141  4965      175    6   31    283
# 7     8            thala      220      193  4746       84    0   23    413
# 8     9    Robin Uthappa      193      186  4722       87    0   25    379
# 9    10    Gutam Gambhir      154      152  4217       93    0   36    306
# ...

# %%
#to fetch a particular/specific row with single value

dataset[dataset['matches']>=200]
# Out:
#    rank          name  matches  innings  runs  highest 100s  50s  Total
# 0     1       V Kohli      207      199    56      113    5   42    406
# 2     3  Rohit Sharma      213      208    76      109    4   40    421
# 3     4  Suresh Raina      205      200  5528      100    1   39    405
# 7     8         thala      220      193  4746       84    0   23    413

# %%
dataset[((dataset['matches']>200) | (dataset['highest']>=200))]
# Out:
#    rank          name  matches  innings  runs  highest 100s  50s  Total
# 0     1       V Kohli      207      199    56      113    5   42    406
# 2     3  Rohit Sharma      213      208    76      109    4   40    421
# 3     4  Suresh Raina      205      200  5528      100    1   39    405
# 7     8         thala      220      193  4746       84    0   23    413

# %%
dataset[((dataset['matches']>200) & (dataset['highest']>=200))]
# Out:
# Empty DataFrame
# Columns: [rank, name, matches, innings, runs, highest, 100s, 50s, Total]
# Index: []

# %%
#to fetch a particular column using a li

data = ['V Kohli','Suresh Raina']
dataset[dataset['name'].isin(data)]
# Out:
#    rank          name  matches  innings  runs  highest 100s  50s  Total
# 0     1       V Kohli      207      199    56      113    5   42    406
# 3     4  Suresh Raina      205      200  5528      100    1   39    405
